# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
LANGCHAIN_API_KEY = os.getenv("LANGCHAIN_API_KEY")
LANGCHAIN_PROJECT = os.getenv("LANGCHAIN_PROJECT")
LANGCHAIN_TRACING_V2 = os.getenv("LANGCHAIN_TRACING_V2")

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant. Please respond to the queries."),
    ("user", "Question: {question}")
])

# %%
llm = ChatOpenAI(model="gpt-4o-mini")
output_parser = StrOutputParser()
chain = prompt | llm | output_parser

# %%
question = "Who won the football World Cup in 2026?"

response = chain.invoke({
    "question": question
})

print(response)
# Out:
# As of my last knowledge update in October 2021, the 2026 FIFA World Cup has not yet taken place, so I do not have information about the winner. The tournament is scheduled to be held in the United States, Canada, and Mexico. For the latest updates, please check the most current sources.

# %%
import os

print("OpenAI:", bool(os.getenv("OPENAI_API_KEY")))
print("LangSmith:", bool(os.getenv("LANGCHAIN_API_KEY")))
print("Project:", os.getenv("LANGCHAIN_PROJECT"))
print("Tracing:", os.getenv("LANGCHAIN_TRACING_V2"))
# Out:
# OpenAI: True
# LangSmith: True
# Project: chatbot
# Tracing: true
